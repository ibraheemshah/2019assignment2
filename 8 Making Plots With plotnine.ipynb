# %%
conda install -c conda-forge plotnine
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import plotnine as p9

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length')))
# Out:
# <ggplot: (-9223371924608760456)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
# Out:
# <ggplot: (-9223371924608760488)>

# %%
# Create
surveys_plot = p9.ggplot(data=surveys_complete,
                         mapping=p9.aes(x='weight', y='hindfoot_length'))

# Draw the plot
surveys_plot + p9.geom_point()
# Out:
# <ggplot: (-9223371924607428548)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
# Out:
# <ggplot: (-9223371924607174708)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (-9223371924608749808)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1, color='blue')
)
# Out:
# <ggplot: (-9223371924604158136)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (-9223371924604581944)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
)
# Out:
# <ggplot: (-9223371924607392268)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
)
# Out:
# <ggplot: (-9223371924607231736)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (-9223371924607329436)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_boxplot()
)
# Out:
# <ggplot: (-9223371924599333804)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_boxplot(alpha=0.)
)
# Out:
# <ggplot: (-9223371924607294952)>

# %%
yearly_counts = surveys_complete.groupby(['year', 'species_id'])['species_id'].count()
yearly_counts
# Out:
# year  species_id
# 1977  DM            181
#       DO             12
#       DS             29
#       OL              1
#       OX              2
#                    ...
# 2002  PP            375
#       RM             20
#       RO              7
#       SF              5
#       SH              9
# Name: species_id, Length: 332, dtype: int64

# %%
yearly_counts = yearly_counts.reset_index(name='counts')
yearly_counts
# Out:
#      year species_id  counts
# 0    1977         DM     181
# 1    1977         DO      12
# 2    1977         DS      29
# 3    1977         OL       1
# 4    1977         OX       2
# ..    ...        ...     ...
# 327  2002         PP     375
# 328  2002         RM      20
# 329  2002         RO       7
# 330  2002         SF       5
# 331  2002         SH       9
#
# [332 rows x 3 columns]

# %%
(p9.ggplot(data=yearly_counts,
           mapping=p9.aes(x='year',
                          y='counts'))
    + p9.geom_line()
)
# Out:
# <ggplot: (-9223371924607068752)>

# %%
(p9.ggplot(data=yearly_counts,
           mapping=p9.aes(x='year',
                          y='counts',
                          color='species_id'))
    + p9.geom_line()
)
# Out:
# <ggplot: (-9223371924607065640)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (-9223371924608778768)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("sex")
)
# Out:
# <ggplot: (-9223371924599699128)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("plot_id")
)
# Out:
# <ggplot: (-9223371924604644404)>

# %%
# only select the years of interest
survey_2000 = surveys_complete[surveys_complete["year"].isin([2000, 2001])]

(p9.ggplot(data=survey_2000,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_grid("year ~ sex")
)
# Out:
# <ggplot: (-9223371924597632128)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
)
# Out:
# <ggplot: (-9223371924597632024)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (-9223371924606742800)>

# %%
my_custom_theme = p9.theme(axis_text_x = p9.element_text(color="grey", size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color="grey", size=10))
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + my_custom_theme
)
# Out:
# <ggplot: (-9223371924607453512)>

# %%
my_plot = (p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
my_plot.save("scatterplot.png", width=10, height=10, dpi=300)
# Out:
# F:\anaconda\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 10 x 10 in image.
#   from_inches(height, units), units), PlotnineWarning)
# F:\anaconda\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: scatterplot.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

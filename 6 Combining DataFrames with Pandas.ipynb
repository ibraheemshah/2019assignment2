# %%
import pandas as pd
surveys_df = pd.read_csv("E:\surveys.csv",
                         keep_default_na=False, na_values=[""])
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
species_df = pd.read_csv("E:\species.csv",
                         keep_default_na=False, na_values=[""])
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
survey_sub = surveys_df.head(10)
survey_sub_last10 = surveys_df.tail(10)
survey_sub_last10=survey_sub_last10.reset_index(drop=True)

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
vertical_stack.to_csv('data_output/out.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8c7519d2da9f> in <module>
# ----> 1 vertical_stack.to_csv('data_output/out.csv', index=False)
#
# NameError: name 'vertical_stack' is not defined

# %%
new_output = pd.read_csv('data_output/out.csv', keep_default_na=False, na_values=[""])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6a516cd1a634> in <module>
# ----> 1 new_output = pd.read_csv('data_output/out.csv', keep_default_na=False, na_values=[""])
#
# NameError: name 'pd' is not defined

# %%
survey_sub = surveys_df.head(10)
species_sub = pd.read_csv('E:\speciesSubset.csv', keep_default_na=False, na_values=[""])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-98b0dfe2ccf4> in <module>
# ----> 1 survey_sub = surveys_df.head(10)
#       2 species_sub = pd.read_csv('E:\speciesSubset.csv', keep_default_na=False, na_values=[""])
#
# NameError: name 'surveys_df' is not defined

# %%
species_sub.columns
    Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')
survey_sub.columns
    Index([u'record_id', u'month', u'day', u'year', u'plot_id', u'species_id',
       u'sex', u'hindfoot_length', u'weight'], dtype='object')
# Out:
#   File "<ipython-input-20-8eae41e3b0b7>", line 2
#     Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')
#     ^
# IndentationError: unexpected indent

# %%
merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
merged_inner.shape
merged_inner
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9b80aab72cf9> in <module>
# ----> 1 merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
#       2 merged_inner.shape
#       3 merged_inner
#
# NameError: name 'pd' is not defined

# %%
merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-3a2f4408f283> in <module>
# ----> 1 merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')
#       2 merged_left
#
# NameError: name 'pd' is not defined

# %%
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4bd032bc12e0> in <module>
# ----> 1 merged_left[ pd.isnull(merged_left.genus) ]
#
# NameError: name 'merged_left' is not defined
